# %% [markdown]
# Applied Data Science Capstone-Week 5

# %%
# !pip install bs4
# !pip install geopy
import requests
from bs4 import BeautifulSoup
import pandas as pd
from geopy.geocoders import Nominatim
import folium
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.cm as cm
import matplotlib.colors as colors
# Out:
# Requirement already satisfied: bs4 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from bs4) (4.9.1)
# Requirement already satisfied: soupsieve>1.2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from beautifulsoup4->bs4) (2.0.1)
# Requirement already satisfied: geopy in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (1.22.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from geopy) (1.50)

# %% [markdown]
# The following cell contains the code for: 1) Creating a Dataframe via Web Scraping 2) Adding the Latitude and Longitude coordinates of each Capital City to the Dataframe

# %%
urlData = requests.get('https://en.wikipedia.org/wiki/List_of_state_and_union_territory_capitals_in_India').text
soup=BeautifulSoup(urlData,'html.parser')
soupTableDataStates=soup.find_all('table')[1].find_all('td')
stateUT=[]
for i in range(1,len(soupTableDataStates),6):
    if '(Summer)' in soupTableDataStates[i].text:
        stateUT.append(soupTableDataStates[i].text.split("(Summer)")[0].strip())
        if ']' in soupTableDataStates[i].text.split("(Summer)")[1].split("(Winter)")[0]:
            stateUT.append(soupTableDataStates[i].text.split("(Summer)")[1].split("(Winter)")[0].split("]")[1].strip())
        else:
            stateUT.append(soupTableDataStates[i].text.split("(Summer)")[1].split("(Winter)")[0].strip())
    elif '(' in soupTableDataStates[i].text:
        stateUT.append(soupTableDataStates[i].text.split("(")[0].strip())
    else:
        stateUT.append(soupTableDataStates[i].text.split("[")[0].strip())
df=pd.DataFrame(data=[stateUT]).transpose()
df.columns=['Capital City']
df['Latitude']=0
df['Longitude']=0
geolocator=Nominatim(user_agent="India")
for index, row in df.iterrows(): 
    df.loc[index, 'Latitude']='None' if geolocator.geocode(row['Capital City'])==None else geolocator.geocode(row['Capital City']).latitude
    df.loc[index, 'Longitude']='None' if geolocator.geocode(row['Capital City'])==None else geolocator.geocode(row['Capital City']).longitude
df.drop_duplicates(subset="Capital City",keep='first',inplace=True) 
df.reset_index(inplace=True,drop=True) 
df
# Out:
#           Capital City   Latitude  Longitude
# 0           Port Blair  11.664535  92.739045
# 1            Amaravati  16.574420  80.355608
# 2             Itanagar  27.097966  93.623729
# 3               Dispur  26.151308  91.793380
# 4                Patna  25.609324  85.123525
# 5           Chandigarh  30.719402  76.764655
# 6          Naya Raipur  21.161027  81.786441
# 7                Daman  20.420005  72.863763
# 8            New Delhi  28.614179  77.202266
# 9               Panaji  15.498995  73.828214
# 10         Gandhinagar  23.223288  72.649227
# 11              Shimla  31.104153  77.170973
# 12            Srinagar  34.074744  74.820444
# 13               Jammu  32.718561  74.858092
# 14              Ranchi  23.370035  85.325013
# 15           Bangalore  12.979120  77.591300
# 16  Thiruvananthapuram   8.505891  76.957048
# 17                 Leh  34.164203  77.584813
# 18              Kargil  34.420894  75.665486
# 19           Kavaratti  10.559050  72.636569
# 20              Bhopal  23.258486  77.401989
# 21              Mumbai  18.938771  72.835335
# 22              Imphal  24.800609  93.937000
# 23            Shillong  25.576045  91.882528
# 24              Aizawl  23.741409  92.720930
# 25              Kohima  25.750000  94.166667
# 26         Bhubaneswar  20.266777  85.843559
# 27         Pondicherry  11.934057  79.830645
# 28              Jaipur  26.916194  75.820349
# 29             Gangtok  27.329046  88.612267
# 30             Chennai  13.080172  80.283833
# 31           Hyderabad  17.388786  78.461065
# 32            Agartala  23.831238  91.282382
# 33             Lucknow  26.838100  80.934600
# 34            Dehradun  30.325565  78.043681
# 35             Kolkata  22.545412  88.356775

# %% [markdown]
# The following cell contains the code for visualizing the capital cities of India

# %%
address='India'
geolocator=Nominatim(user_agent="india_explorer")
location=geolocator.geocode(address)
latitude=location.latitude
longitude=location.longitude
print('The geograpical coordinates of India are {}, {}.'.format(latitude, longitude))
map_india=folium.Map(location=[latitude, longitude], zoom_start=4)
for lat, lng, label in zip(df['Latitude'], df['Longitude'], df['Capital City']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_india)  
map_india
# Out:
# The geograpical coordinates of India are 22.3511148, 78.6677428.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# The following cell contains the code for exploring the capital cities of India

# %%
CLIENT_ID='VSFLJD2ZWXQECAKVX35E31LYZHJGVPDLLWT50TBBNDDD1TD5' # your Foursquare ID
CLIENT_SECRET='45LTCSIVWTECKFB010KP5BEQ3HCISK2MHASG2BNKKS2X2IWF' # your Foursquare Secret
VERSION='20180605' # Foursquare API version
LIMIT=100
radius=500
venues_list=[]
for city, lat, lng in zip(df['Capital City'], df['Latitude'], df['Longitude']):
    url='https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
        CLIENT_ID, 
        CLIENT_SECRET, 
        VERSION, 
        lat, 
        lng, 
        radius, 
        LIMIT)
    results=requests.get(url).json()["response"]['groups'][0]['items']
    venues_list.append([(
        city, 
        lat, 
        lng, 
        v['venue']['name'], 
        v['venue']['location']['lat'], 
        v['venue']['location']['lng'],  
        v['venue']['categories'][0]['name']) for v in results])
india_venues=pd.DataFrame([item for venue_list in venues_list for item in venue_list])
india_venues.columns=['Capital City', 
              'City Latitude', 
              'City Longitude', 
              'Venue', 
              'Venue Latitude', 
              'Venue Longitude', 
              'Venue Category']
india_venues
# Out:
#     Capital City  City Latitude  City Longitude                       Venue  \
# 0     Port Blair      11.664535       92.739045          MM Tours & Travels
# 1     Port Blair      11.664535       92.739045              Sagar Emporium
# 2     Port Blair      11.664535       92.739045       andaman fried chicken
# 3     Port Blair      11.664535       92.739045                     Wandoor
# 4      Amaravati      16.574420       80.355608  Amaravathi Buddhist Museum
# ..           ...            ...             ...                         ...
# 244      Kolkata      22.545412       88.356775         Shisha Reincarnated
# 245      Kolkata      22.545412       88.356775             Cafe Coffee Day
# 246      Kolkata      22.545412       88.356775                  Pantaloons
# 247      Kolkata      22.545412       88.356775                  Urban Desi
# 248      Kolkata      22.545412       88.356775                    Cafe 4/1
#
#      Venue Latitude  Venue Longitude              Venue Category
# 0         11.664988        92.738922  Tourist Information Center
# 1         11.663861        92.735847         Arts & Crafts Store
# 2         11.667943        92.737825        Fast Food Restaurant
# 3         11.667975        92.737324                       Beach
# 4         16.575949        80.356569              History Museum
# ..              ...              ...                         ...
# 244       22.546911        88.353341                   Nightclub
# 245       22.545478        88.352501                        Café
# 246       22.546955        88.353446              Clothing Store
# 247       22.544248        88.352160           Indian Restaurant
# 248       22.546093        88.352437                        Café
#
# [249 rows x 7 columns]

# %% [markdown]
# The following cell contains the code for listing the various venues in the capital cities of India

# %%
india_venue_categories = india_venues.groupby(['Capital City', 'Venue Category']).count()
india_venue_categories.drop(['City Latitude', 'City Longitude',  'Venue Latitude', 'Venue Longitude'], axis = 1, inplace=True)
india_venue_categories.rename(columns = {'Venue':'Count'}, inplace = True) 
india_venue_categories.drop(['Count'], axis = 1, inplace=True)
india_venue_categories
# Out:
# Empty DataFrame
# Columns: []
# Index: [(Agartala, Electronics Store), (Agartala, Fast Food Restaurant), (Agartala, Indian Restaurant), (Agartala, Multiplex), (Aizawl, Bakery), (Aizawl, Restaurant), (Amaravati, History Museum), (Bangalore, Capitol Building), (Bangalore, Garden), (Bangalore, Park), (Bangalore, Vineyard), (Bhopal, Airport), (Bhopal, Food Court), (Bhopal, Historic Site), (Bhopal, Market), (Bhubaneswar, Asian Restaurant), (Bhubaneswar, Convenience Store), (Bhubaneswar, Fast Food Restaurant), (Bhubaneswar, Hotel), (Bhubaneswar, Jewelry Store), (Bhubaneswar, Men's Store), (Chandigarh, American Restaurant), (Chandigarh, Asian Restaurant), (Chandigarh, Bakery), (Chandigarh, Café), (Chandigarh, Fast Food Restaurant), (Chandigarh, Fried Chicken Joint), (Chandigarh, Ice Cream Shop), (Chandigarh, Indian Restaurant), (Chandigarh, Italian Restaurant), (Chandigarh, Sandwich Place), (Chandigarh, Snack Place), (Chennai, Harbor / Marina), (Chennai, Historic Site), (Chennai, Museum), (Chennai, Pharmacy), (Chennai, Train Station), (Dehradun, Bakery), (Dehradun, Café), (Dehradun, Coffee Shop), (Dehradun, Fast Food Restaurant), (Dehradun, Flea Market), (Dehradun, Food Court), (Dehradun, Hotel), (Dehradun, Ice Cream Shop), (Dehradun, Indian Restaurant), (Dehradun, Sandwich Place), (Dispur, ATM), (Dispur, Northeast Indian Restaurant), (Gandhinagar, Arts & Entertainment), (Gandhinagar, Gym), (Gandhinagar, Ice Cream Shop), (Gandhinagar, Park), (Gandhinagar, Recreation Center), (Gangtok, Café), (Gangtok, Coffee Shop), (Gangtok, Dumpling Restaurant), (Gangtok, Garden), (Gangtok, Market), (Gangtok, Plaza), (Gangtok, Sandwich Place), (Hyderabad, Afghan Restaurant), (Hyderabad, Indian Restaurant), (Hyderabad, Snack Place), (Imphal, Café), (Imphal, Fried Chicken Joint), (Imphal, Indian Restaurant), (Imphal, Paper / Office Supplies Store), (Jaipur, Coffee Shop), (Jaipur, Historic Site), (Jaipur, Market), (Jaipur, Shopping Mall), (Jammu, Asian Restaurant), (Kavaratti, Bank), (Kolkata, Bakery), (Kolkata, Café), (Kolkata, Clothing Store), (Kolkata, Hotel), (Kolkata, Indian Restaurant), (Kolkata, Mexican Restaurant), (Kolkata, Nightclub), (Kolkata, Performing Arts Venue), (Kolkata, Shopping Mall), (Kolkata, Tea Room), (Leh, Bakery), (Leh, Coffee Shop), (Leh, Himalayan Restaurant), (Leh, Hotel), (Leh, Indian Restaurant), (Leh, Multicuisine Indian Restaurant), (Leh, Noodle House), (Leh, Palace), (Leh, Shopping Plaza), (Leh, Tibetan Restaurant), (Lucknow, Fast Food Restaurant), (Mumbai, Athletics & Sports), (Mumbai, Bar), (Mumbai, Café), (Mumbai, Chinese Restaurant), (Mumbai, Coffee Shop), ...]
#
# [200 rows x 0 columns]

# %% [markdown]
# The following cell contains the code for listing the various types of restaurants in the capital cities of India

# %%
india_venue_categories_col=india_venue_categories.reset_index()
india_venue_restaurants=india_venue_categories_col[india_venue_categories_col['Venue Category'].str.contains("Restaurant")]
india_venue_restaurants.rename(columns = {'Venue Category':'Restaurant Category'}, inplace = True) 
india_venue_restaurants_list=india_venue_restaurants.groupby(['Capital City', 'Restaurant Category']).count()
india_venue_restaurants_list
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/pandas/core/frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# Empty DataFrame
# Columns: []
# Index: [(Agartala, Fast Food Restaurant), (Agartala, Indian Restaurant), (Aizawl, Restaurant), (Bhubaneswar, Asian Restaurant), (Bhubaneswar, Fast Food Restaurant), (Chandigarh, American Restaurant), (Chandigarh, Asian Restaurant), (Chandigarh, Fast Food Restaurant), (Chandigarh, Indian Restaurant), (Chandigarh, Italian Restaurant), (Dehradun, Fast Food Restaurant), (Dehradun, Indian Restaurant), (Dispur, Northeast Indian Restaurant), (Gangtok, Dumpling Restaurant), (Hyderabad, Afghan Restaurant), (Hyderabad, Indian Restaurant), (Imphal, Indian Restaurant), (Jammu, Asian Restaurant), (Kolkata, Indian Restaurant), (Kolkata, Mexican Restaurant), (Leh, Himalayan Restaurant), (Leh, Indian Restaurant), (Leh, Multicuisine Indian Restaurant), (Leh, Tibetan Restaurant), (Lucknow, Fast Food Restaurant), (Mumbai, Chinese Restaurant), (Mumbai, Indian Restaurant), (Mumbai, Seafood Restaurant), (Naya Raipur, Indian Restaurant), (Panaji, American Restaurant), (Panaji, Asian Restaurant), (Panaji, Indian Restaurant), (Panaji, Mughlai Restaurant), (Panaji, Portuguese Restaurant), (Panaji, Punjabi Restaurant), (Panaji, Restaurant), (Panaji, Seafood Restaurant), (Panaji, Southern / Soul Food Restaurant), (Panaji, Vegetarian / Vegan Restaurant), (Pondicherry, Chinese Restaurant), (Pondicherry, Fast Food Restaurant), (Pondicherry, French Restaurant), (Pondicherry, Indian Restaurant), (Pondicherry, Italian Restaurant), (Pondicherry, Restaurant), (Pondicherry, Vegetarian / Vegan Restaurant), (Port Blair, Fast Food Restaurant), (Ranchi, Indian Restaurant), (Shillong, Asian Restaurant), (Shillong, Fast Food Restaurant), (Shimla, Chinese Restaurant), (Shimla, Indian Restaurant), (Shimla, Restaurant), (Srinagar, Restaurant)]

# %% [markdown]
# The following cell contains the code for listing out the top five most common restaurant types in each capital city of India

# %%
india_restaurants_onehot=pd.get_dummies(india_venue_restaurants[['Restaurant Category']], prefix="", prefix_sep="")
india_restaurants_onehot['Capital City']=india_venue_restaurants['Capital City']
fixed_columns=[india_restaurants_onehot.columns[-1]] + list(india_restaurants_onehot.columns[:-1])
india_restaurants_onehot=india_restaurants_onehot[fixed_columns]
india_restaurants_grouped=india_restaurants_onehot.groupby('Capital City').mean().reset_index()
num_top_venues=5
for hood in india_restaurants_grouped['Capital City']:
    print("----"+hood+"----")
    temp=india_restaurants_grouped[india_restaurants_grouped['Capital City'] == hood].T.reset_index()
    temp.columns=['restaurant','freq']
    temp=temp.iloc[1:]
    temp['freq']=temp['freq'].astype(float)
    temp=temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Agartala----
#                        restaurant  freq
# 0            Fast Food Restaurant   0.5
# 1               Indian Restaurant   0.5
# 2               Afghan Restaurant   0.0
# 3  Multicuisine Indian Restaurant   0.0
# 4              Tibetan Restaurant   0.0
#
#
# ----Aizawl----
#                         restaurant  freq
# 0                       Restaurant   1.0
# 1                Afghan Restaurant   0.0
# 2               Mughlai Restaurant   0.0
# 3               Tibetan Restaurant   0.0
# 4  Southern / Soul Food Restaurant   0.0
#
#
# ----Bhubaneswar----
#                        restaurant  freq
# 0                Asian Restaurant   0.5
# 1            Fast Food Restaurant   0.5
# 2               Afghan Restaurant   0.0
# 3  Multicuisine Indian Restaurant   0.0
# 4              Tibetan Restaurant   0.0
#
#
# ----Chandigarh----
#              restaurant  freq
# 0      Asian Restaurant   0.2
# 1  Fast Food Restaurant   0.2
# 2     Indian Restaurant   0.2
# 3    Italian Restaurant   0.2
# 4   American Restaurant   0.2
#
#
# ----Dehradun----
#                        restaurant  freq
# 0            Fast Food Restaurant   0.5
# 1               Indian Restaurant   0.5
# 2               Afghan Restaurant   0.0
# 3  Multicuisine Indian Restaurant   0.0
# 4              Tibetan Restaurant   0.0
#
#
# ----Dispur----
#                         restaurant  freq
# 0      Northeast Indian Restaurant   1.0
# 1                Afghan Restaurant   0.0
# 2               Mughlai Restaurant   0.0
# 3               Tibetan Restaurant   0.0
# 4  Southern / Soul Food Restaurant   0.0
#
#
# ----Gangtok----
#                         restaurant  freq
# 0              Dumpling Restaurant   1.0
# 1                Afghan Restaurant   0.0
# 2               Mughlai Restaurant   0.0
# 3               Tibetan Restaurant   0.0
# 4  Southern / Soul Food Restaurant   0.0
#
#
# ----Hyderabad----
#                         restaurant  freq
# 0                Afghan Restaurant   0.5
# 1                Indian Restaurant   0.5
# 2               Mughlai Restaurant   0.0
# 3               Tibetan Restaurant   0.0
# 4  Southern / Soul Food Restaurant   0.0
#
#
# ----Imphal----
#                         restaurant  freq
# 0                Indian Restaurant   1.0
# 1                Afghan Restaurant   0.0
# 2               Mughlai Restaurant   0.0
# 3               Tibetan Restaurant   0.0
# 4  Southern / Soul Food Restaurant   0.0
#
#
# ----Jammu----
#                         restaurant  freq
# 0                 Asian Restaurant   1.0
# 1                Afghan Restaurant   0.0
# 2               Mughlai Restaurant   0.0
# 3               Tibetan Restaurant   0.0
# 4  Southern / Soul Food Restaurant   0.0
#
#
# ----Kolkata----
#                         restaurant  freq
# 0               Mexican Restaurant   0.5
# 1                Indian Restaurant   0.5
# 2               Mughlai Restaurant   0.0
# 3               Tibetan Restaurant   0.0
# 4  Southern / Soul Food Restaurant   0.0
#
#
# ----Leh----
#                        restaurant  freq
# 0  Multicuisine Indian Restaurant  0.25
# 1              Tibetan Restaurant  0.25
# 2            Himalayan Restaurant  0.25
# 3               Indian Restaurant  0.25
# 4               Afghan Restaurant  0.00
#
#
# ----Lucknow----
#                         restaurant  freq
# 0             Fast Food Restaurant   1.0
# 1                Afghan Restaurant   0.0
# 2               Mughlai Restaurant   0.0
# 3               Tibetan Restaurant   0.0
# 4  Southern / Soul Food Restaurant   0.0
#
#
# ----Mumbai----
#                        restaurant  freq
# 0              Chinese Restaurant  0.33
# 1              Seafood Restaurant  0.33
# 2               Indian Restaurant  0.33
# 3               Afghan Restaurant  0.00
# 4  Multicuisine Indian Restaurant  0.00
#
#
# ----Naya Raipur----
#                         restaurant  freq
# 0                Indian Restaurant   1.0
# 1                Afghan Restaurant   0.0
# 2               Mughlai Restaurant   0.0
# 3               Tibetan Restaurant   0.0
# 4  Southern / Soul Food Restaurant   0.0
#
#
# ----Panaji----
#                         restaurant  freq
# 0    Vegetarian / Vegan Restaurant   0.1
# 1                 Asian Restaurant   0.1
# 2  Southern / Soul Food Restaurant   0.1
# 3               Seafood Restaurant   0.1
# 4                       Restaurant   0.1
#
#
# ----Pondicherry----
#                       restaurant  freq
# 0  Vegetarian / Vegan Restaurant  0.14
# 1             Chinese Restaurant  0.14
# 2           Fast Food Restaurant  0.14
# 3              French Restaurant  0.14
# 4              Indian Restaurant  0.14
#
#
# ----Port Blair----
#                         restaurant  freq
# 0             Fast Food Restaurant   1.0
# 1                Afghan Restaurant   0.0
# 2               Mughlai Restaurant   0.0
# 3               Tibetan Restaurant   0.0
# 4  Southern / Soul Food Restaurant   0.0
#
#
# ----Ranchi----
#                         restaurant  freq
# 0                Indian Restaurant   1.0
# 1                Afghan Restaurant   0.0
# 2               Mughlai Restaurant   0.0
# 3               Tibetan Restaurant   0.0
# 4  Southern / Soul Food Restaurant   0.0
#
#
# ----Shillong----
#                        restaurant  freq
# 0                Asian Restaurant   0.5
# 1            Fast Food Restaurant   0.5
# 2               Afghan Restaurant   0.0
# 3  Multicuisine Indian Restaurant   0.0
# 4              Tibetan Restaurant   0.0
#
#
# ----Shimla----
#                        restaurant  freq
# 0              Chinese Restaurant  0.33
# 1                      Restaurant  0.33
# 2               Indian Restaurant  0.33
# 3               Afghan Restaurant  0.00
# 4  Multicuisine Indian Restaurant  0.00
#
#
# ----Srinagar----
#                         restaurant  freq
# 0                       Restaurant   1.0
# 1                Afghan Restaurant   0.0
# 2               Mughlai Restaurant   0.0
# 3               Tibetan Restaurant   0.0
# 4  Southern / Soul Food Restaurant   0.0

# %% [markdown]
# The following cell contains the code for creating a dataframe that stores the top ten restaurant types of each capital city of India

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories=row.iloc[1:]
    row_categories_sorted=row_categories.sort_values(ascending=False)
    return row_categories_sorted.index.values[0:num_top_venues]
num_top_venues=10
indicators=['st', 'nd', 'rd']
columns=['Capital City']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Restaurant'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Restaurant'.format(ind+1))
india_restaurants_sorted=pd.DataFrame(columns=columns)
india_restaurants_sorted['Capital City']=india_restaurants_grouped['Capital City']
for ind in np.arange(india_restaurants_grouped.shape[0]):
    india_restaurants_sorted.iloc[ind, 1:]=return_most_common_venues(india_restaurants_grouped.iloc[ind, :], num_top_venues)
india_restaurants_sorted
# Out:
#    Capital City     1st Most Common Restaurant  \
# 0      Agartala           Fast Food Restaurant
# 1        Aizawl                     Restaurant
# 2   Bhubaneswar               Asian Restaurant
# 3    Chandigarh             Italian Restaurant
# 4      Dehradun           Fast Food Restaurant
# 5        Dispur    Northeast Indian Restaurant
# 6       Gangtok            Dumpling Restaurant
# 7     Hyderabad              Afghan Restaurant
# 8        Imphal              Indian Restaurant
# 9         Jammu               Asian Restaurant
# 10      Kolkata             Mexican Restaurant
# 11          Leh              Indian Restaurant
# 12      Lucknow           Fast Food Restaurant
# 13       Mumbai             Seafood Restaurant
# 14  Naya Raipur              Indian Restaurant
# 15       Panaji  Vegetarian / Vegan Restaurant
# 16  Pondicherry  Vegetarian / Vegan Restaurant
# 17   Port Blair           Fast Food Restaurant
# 18       Ranchi              Indian Restaurant
# 19     Shillong               Asian Restaurant
# 20       Shimla                     Restaurant
# 21     Srinagar                     Restaurant
#
#          2nd Most Common Restaurant     3rd Most Common Restaurant  \
# 0                 Indian Restaurant  Vegetarian / Vegan Restaurant
# 1     Vegetarian / Vegan Restaurant             Italian Restaurant
# 2              Fast Food Restaurant  Vegetarian / Vegan Restaurant
# 3               American Restaurant               Asian Restaurant
# 4                 Indian Restaurant  Vegetarian / Vegan Restaurant
# 5     Vegetarian / Vegan Restaurant             Italian Restaurant
# 6     Vegetarian / Vegan Restaurant             Italian Restaurant
# 7                 Indian Restaurant             Italian Restaurant
# 8     Vegetarian / Vegan Restaurant             Italian Restaurant
# 9     Vegetarian / Vegan Restaurant             Italian Restaurant
# 10                Indian Restaurant             Italian Restaurant
# 11   Multicuisine Indian Restaurant           Himalayan Restaurant
# 12    Vegetarian / Vegan Restaurant             Italian Restaurant
# 13               Chinese Restaurant              Indian Restaurant
# 14    Vegetarian / Vegan Restaurant             Italian Restaurant
# 15  Southern / Soul Food Restaurant             Seafood Restaurant
# 16               Italian Restaurant                     Restaurant
# 17    Vegetarian / Vegan Restaurant             Italian Restaurant
# 18    Vegetarian / Vegan Restaurant             Italian Restaurant
# 19             Fast Food Restaurant  Vegetarian / Vegan Restaurant
# 20               Chinese Restaurant              Indian Restaurant
# 21    Vegetarian / Vegan Restaurant             Italian Restaurant
#
#        4th Most Common Restaurant     5th Most Common Restaurant  \
# 0              Italian Restaurant            American Restaurant
# 1             American Restaurant               Asian Restaurant
# 2              Italian Restaurant            American Restaurant
# 3            Fast Food Restaurant              Indian Restaurant
# 4              Italian Restaurant            American Restaurant
# 5             American Restaurant               Asian Restaurant
# 6             American Restaurant               Asian Restaurant
# 7             American Restaurant               Asian Restaurant
# 8             American Restaurant               Asian Restaurant
# 9             American Restaurant             Chinese Restaurant
# 10            American Restaurant               Asian Restaurant
# 11             Tibetan Restaurant  Vegetarian / Vegan Restaurant
# 12            American Restaurant               Asian Restaurant
# 13  Vegetarian / Vegan Restaurant             Italian Restaurant
# 14            American Restaurant               Asian Restaurant
# 15                     Restaurant             Punjabi Restaurant
# 16             Chinese Restaurant           Fast Food Restaurant
# 17            American Restaurant               Asian Restaurant
# 18            American Restaurant               Asian Restaurant
# 19             Italian Restaurant            American Restaurant
# 20  Vegetarian / Vegan Restaurant             Italian Restaurant
# 21            American Restaurant               Asian Restaurant
#
#        6th Most Common Restaurant 7th Most Common Restaurant  \
# 0                Asian Restaurant         Chinese Restaurant
# 1              Chinese Restaurant        Dumpling Restaurant
# 2              Chinese Restaurant        Dumpling Restaurant
# 3   Vegetarian / Vegan Restaurant         Chinese Restaurant
# 4                Asian Restaurant         Chinese Restaurant
# 5              Chinese Restaurant        Dumpling Restaurant
# 6              Chinese Restaurant       Fast Food Restaurant
# 7              Chinese Restaurant        Dumpling Restaurant
# 8              Chinese Restaurant        Dumpling Restaurant
# 9             Dumpling Restaurant       Fast Food Restaurant
# 10             Chinese Restaurant        Dumpling Restaurant
# 11            American Restaurant           Asian Restaurant
# 12             Chinese Restaurant        Dumpling Restaurant
# 13            American Restaurant           Asian Restaurant
# 14             Chinese Restaurant        Dumpling Restaurant
# 15          Portuguese Restaurant        American Restaurant
# 16              French Restaurant          Indian Restaurant
# 17             Chinese Restaurant        Dumpling Restaurant
# 18             Chinese Restaurant        Dumpling Restaurant
# 19             Chinese Restaurant        Dumpling Restaurant
# 20            American Restaurant           Asian Restaurant
# 21             Chinese Restaurant        Dumpling Restaurant
#
#    8th Most Common Restaurant 9th Most Common Restaurant  \
# 0         Dumpling Restaurant          French Restaurant
# 1        Fast Food Restaurant          French Restaurant
# 2           French Restaurant       Himalayan Restaurant
# 3         Dumpling Restaurant          French Restaurant
# 4         Dumpling Restaurant          French Restaurant
# 5        Fast Food Restaurant          French Restaurant
# 6           French Restaurant       Himalayan Restaurant
# 7        Fast Food Restaurant          French Restaurant
# 8        Fast Food Restaurant          French Restaurant
# 9           French Restaurant       Himalayan Restaurant
# 10       Fast Food Restaurant          French Restaurant
# 11         Chinese Restaurant        Dumpling Restaurant
# 12          French Restaurant       Himalayan Restaurant
# 13        Dumpling Restaurant       Fast Food Restaurant
# 14       Fast Food Restaurant          French Restaurant
# 15           Asian Restaurant         Mughlai Restaurant
# 16        American Restaurant           Asian Restaurant
# 17          French Restaurant       Himalayan Restaurant
# 18       Fast Food Restaurant          French Restaurant
# 19          French Restaurant       Himalayan Restaurant
# 20        Dumpling Restaurant       Fast Food Restaurant
# 21       Fast Food Restaurant          French Restaurant
#
#    10th Most Common Restaurant
# 0         Himalayan Restaurant
# 1         Himalayan Restaurant
# 2            Indian Restaurant
# 3         Himalayan Restaurant
# 4         Himalayan Restaurant
# 5         Himalayan Restaurant
# 6            Indian Restaurant
# 7         Himalayan Restaurant
# 8         Himalayan Restaurant
# 9            Indian Restaurant
# 10        Himalayan Restaurant
# 11        Fast Food Restaurant
# 12           Indian Restaurant
# 13           French Restaurant
# 14        Himalayan Restaurant
# 15           Indian Restaurant
# 16         Dumpling Restaurant
# 17           Indian Restaurant
# 18        Himalayan Restaurant
# 19           Indian Restaurant
# 20           French Restaurant
# 21        Himalayan Restaurant

# %% [markdown]
# The following cell contains the code for creating a dataframe that stores the cluster as well as the top ten restaurant types of each capital city of India

# %%
kclusters=5
india_restaurants_grouped_clustering=india_restaurants_grouped.drop('Capital City', 1)
kmeans=KMeans(n_init=300, n_clusters=kclusters, random_state=5).fit(india_restaurants_grouped_clustering)
india_restaurants_sorted.insert(0, 'Cluster Labels', kmeans.labels_)
india_restaurants_sorted['Latitude']=0
india_restaurants_sorted['Longitude']=0
geolocator=Nominatim(user_agent="India")
for index, row in india_restaurants_sorted.iterrows(): 
    india_restaurants_sorted.loc[index, 'Latitude']='None' if geolocator.geocode(row['Capital City'])==None else geolocator.geocode(row['Capital City']).latitude
    india_restaurants_sorted.loc[index, 'Longitude']='None' if geolocator.geocode(row['Capital City'])==None else geolocator.geocode(row['Capital City']).longitude
india_restaurants_sorted
# Out:
#     Cluster Labels Capital City     1st Most Common Restaurant  \
# 0                1     Agartala           Fast Food Restaurant
# 1                2       Aizawl                     Restaurant
# 2                4  Bhubaneswar               Asian Restaurant
# 3                3   Chandigarh             Italian Restaurant
# 4                1     Dehradun           Fast Food Restaurant
# 5                3       Dispur    Northeast Indian Restaurant
# 6                3      Gangtok            Dumpling Restaurant
# 7                0    Hyderabad              Afghan Restaurant
# 8                0       Imphal              Indian Restaurant
# 9                4        Jammu               Asian Restaurant
# 10               0      Kolkata             Mexican Restaurant
# 11               3          Leh              Indian Restaurant
# 12               1      Lucknow           Fast Food Restaurant
# 13               3       Mumbai             Seafood Restaurant
# 14               0  Naya Raipur              Indian Restaurant
# 15               3       Panaji  Vegetarian / Vegan Restaurant
# 16               3  Pondicherry  Vegetarian / Vegan Restaurant
# 17               1   Port Blair           Fast Food Restaurant
# 18               0       Ranchi              Indian Restaurant
# 19               4     Shillong               Asian Restaurant
# 20               3       Shimla                     Restaurant
# 21               2     Srinagar                     Restaurant
#
#          2nd Most Common Restaurant     3rd Most Common Restaurant  \
# 0                 Indian Restaurant  Vegetarian / Vegan Restaurant
# 1     Vegetarian / Vegan Restaurant             Italian Restaurant
# 2              Fast Food Restaurant  Vegetarian / Vegan Restaurant
# 3               American Restaurant               Asian Restaurant
# 4                 Indian Restaurant  Vegetarian / Vegan Restaurant
# 5     Vegetarian / Vegan Restaurant             Italian Restaurant
# 6     Vegetarian / Vegan Restaurant             Italian Restaurant
# 7                 Indian Restaurant             Italian Restaurant
# 8     Vegetarian / Vegan Restaurant             Italian Restaurant
# 9     Vegetarian / Vegan Restaurant             Italian Restaurant
# 10                Indian Restaurant             Italian Restaurant
# 11   Multicuisine Indian Restaurant           Himalayan Restaurant
# 12    Vegetarian / Vegan Restaurant             Italian Restaurant
# 13               Chinese Restaurant              Indian Restaurant
# 14    Vegetarian / Vegan Restaurant             Italian Restaurant
# 15  Southern / Soul Food Restaurant             Seafood Restaurant
# 16               Italian Restaurant                     Restaurant
# 17    Vegetarian / Vegan Restaurant             Italian Restaurant
# 18    Vegetarian / Vegan Restaurant             Italian Restaurant
# 19             Fast Food Restaurant  Vegetarian / Vegan Restaurant
# 20               Chinese Restaurant              Indian Restaurant
# 21    Vegetarian / Vegan Restaurant             Italian Restaurant
#
#        4th Most Common Restaurant     5th Most Common Restaurant  \
# 0              Italian Restaurant            American Restaurant
# 1             American Restaurant               Asian Restaurant
# 2              Italian Restaurant            American Restaurant
# 3            Fast Food Restaurant              Indian Restaurant
# 4              Italian Restaurant            American Restaurant
# 5             American Restaurant               Asian Restaurant
# 6             American Restaurant               Asian Restaurant
# 7             American Restaurant               Asian Restaurant
# 8             American Restaurant               Asian Restaurant
# 9             American Restaurant             Chinese Restaurant
# 10            American Restaurant               Asian Restaurant
# 11             Tibetan Restaurant  Vegetarian / Vegan Restaurant
# 12            American Restaurant               Asian Restaurant
# 13  Vegetarian / Vegan Restaurant             Italian Restaurant
# 14            American Restaurant               Asian Restaurant
# 15                     Restaurant             Punjabi Restaurant
# 16             Chinese Restaurant           Fast Food Restaurant
# 17            American Restaurant               Asian Restaurant
# 18            American Restaurant               Asian Restaurant
# 19             Italian Restaurant            American Restaurant
# 20  Vegetarian / Vegan Restaurant             Italian Restaurant
# 21            American Restaurant               Asian Restaurant
#
#        6th Most Common Restaurant 7th Most Common Restaurant  \
# 0                Asian Restaurant         Chinese Restaurant
# 1              Chinese Restaurant        Dumpling Restaurant
# 2              Chinese Restaurant        Dumpling Restaurant
# 3   Vegetarian / Vegan Restaurant         Chinese Restaurant
# 4                Asian Restaurant         Chinese Restaurant
# 5              Chinese Restaurant        Dumpling Restaurant
# 6              Chinese Restaurant       Fast Food Restaurant
# 7              Chinese Restaurant        Dumpling Restaurant
# 8              Chinese Restaurant        Dumpling Restaurant
# 9             Dumpling Restaurant       Fast Food Restaurant
# 10             Chinese Restaurant        Dumpling Restaurant
# 11            American Restaurant           Asian Restaurant
# 12             Chinese Restaurant        Dumpling Restaurant
# 13            American Restaurant           Asian Restaurant
# 14             Chinese Restaurant        Dumpling Restaurant
# 15          Portuguese Restaurant        American Restaurant
# 16              French Restaurant          Indian Restaurant
# 17             Chinese Restaurant        Dumpling Restaurant
# 18             Chinese Restaurant        Dumpling Restaurant
# 19             Chinese Restaurant        Dumpling Restaurant
# 20            American Restaurant           Asian Restaurant
# 21             Chinese Restaurant        Dumpling Restaurant
#
#    8th Most Common Restaurant 9th Most Common Restaurant  \
# 0         Dumpling Restaurant          French Restaurant
# 1        Fast Food Restaurant          French Restaurant
# 2           French Restaurant       Himalayan Restaurant
# 3         Dumpling Restaurant          French Restaurant
# 4         Dumpling Restaurant          French Restaurant
# 5        Fast Food Restaurant          French Restaurant
# 6           French Restaurant       Himalayan Restaurant
# 7        Fast Food Restaurant          French Restaurant
# 8        Fast Food Restaurant          French Restaurant
# 9           French Restaurant       Himalayan Restaurant
# 10       Fast Food Restaurant          French Restaurant
# 11         Chinese Restaurant        Dumpling Restaurant
# 12          French Restaurant       Himalayan Restaurant
# 13        Dumpling Restaurant       Fast Food Restaurant
# 14       Fast Food Restaurant          French Restaurant
# 15           Asian Restaurant         Mughlai Restaurant
# 16        American Restaurant           Asian Restaurant
# 17          French Restaurant       Himalayan Restaurant
# 18       Fast Food Restaurant          French Restaurant
# 19          French Restaurant       Himalayan Restaurant
# 20        Dumpling Restaurant       Fast Food Restaurant
# 21       Fast Food Restaurant          French Restaurant
#
#    10th Most Common Restaurant   Latitude  Longitude
# 0         Himalayan Restaurant  23.831238  91.282382
# 1         Himalayan Restaurant  23.741409  92.720930
# 2            Indian Restaurant  20.266777  85.843559
# 3         Himalayan Restaurant  30.719402  76.764655
# 4         Himalayan Restaurant  30.325565  78.043681
# 5         Himalayan Restaurant  26.151308  91.793380
# 6            Indian Restaurant  27.329046  88.612267
# 7         Himalayan Restaurant  17.388786  78.461065
# 8         Himalayan Restaurant  24.800609  93.937000
# 9            Indian Restaurant  32.718561  74.858092
# 10        Himalayan Restaurant  22.545412  88.356775
# 11        Fast Food Restaurant  34.164203  77.584813
# 12           Indian Restaurant  26.838100  80.934600
# 13           French Restaurant  18.938771  72.835335
# 14        Himalayan Restaurant  21.161027  81.786441
# 15           Indian Restaurant  15.498995  73.828214
# 16         Dumpling Restaurant  11.934057  79.830645
# 17           Indian Restaurant  11.664535  92.739045
# 18        Himalayan Restaurant  23.370035  85.325013
# 19           Indian Restaurant  25.576045  91.882528
# 20           French Restaurant  31.104153  77.170973
# 21        Himalayan Restaurant  34.074744  74.820444

# %% [markdown]
# The following cell contains the code for visualizing the clusters of capital cities of India based on the cuisines served by the popular restaurants located there

# %%
map_clusters=folium.Map(location=[latitude, longitude], zoom_start=4)
x=np.arange(kclusters)
ys=[i + x + (i*x)**2 for i in range(kclusters)]
colors_array=cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow=[colors.rgb2hex(i) for i in colors_array]
markers_colors=[]
for lat, lon, poi, cluster in zip(india_restaurants_sorted['Latitude'], india_restaurants_sorted['Longitude'], india_restaurants_sorted['Capital City'], india_restaurants_sorted['Cluster Labels']):
    label=folium.Popup(str(poi) + ' (Cluster ' + str(cluster) + ')', parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
